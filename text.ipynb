# %% [markdown]
# В данном ноутбуке содержится материал для финальной презентации

# %% [markdown]
# $$\mathcal{W} = \{w_i \}_{i=1}^S - \text{словарь}$$
#
# $$\left\{Q_i\right\}_{i=1}^N, Q_i \in \mathcal{W}^{*} - \text{префиксы запросов}$$
#
# $$\left\{nw_i\right\}_{i=1}^N,  nw_i \in \mathcal{W} - \text{текущие слова}$$
#
# $$ \text{задача классификации: } f:\mathcal{W}^* \rightarrow \mathcal{W} $$
#
# $$\mathcal{p} : \mathcal{W}^* \rightarrow \mathcal{P}(\mathcal{W}), \text{ где } \mathcal{P}(\mathcal{W}) - \text{ вероятностное распределение над } \mathcal{W} $$
#
# $$\mathcal{p_w} : \mathcal{W}^* \rightarrow [0, 1] \text{ вероятность продолжения префикса словом } w \text{ словаря}$$
#
# $$\text{Следовательно }\mathcal{f}(Q) = \max_{i=1}^S \mathcal{p_{w_i}}(Q) $$
#
# $$\hat{f}, \hat{p_i} \text{ оценки } \mathcal{f}, \mathcal{p_i} \text{ соответственно}  $$
#
# $$\text{метрика качества:} \sum_{i=1}^N \mathcal{I}[\hat{f}(Q_i) = nw_i] $$
#
# $$\text{функция потерь - negative log-likelihood loss}  $$
#
# $$\text{loss = } \sum_{i=1}^N [-log(\hat{p}_{nw_i} (Q_i) )] $$

# %% [markdown]
# $\text{аддитивный: }$       $ score(s_t, h_i) = \mathcal{v}_a^{т}tanh( W_a [s_t;, h_i])$
#
# $\text{dot product similarity: }$ $ score(s_t, h_i) = s_t^{т} h_i $
#
# $\text{cosine similarity: } $ $score(s_t, h_i) = cosine[s_t, h_i]$
#
# $\text{location based: }$ $ score(s_t) = W_{a_i} s_t$
#
# $s_t - \text{ итоговый выход сети, } h_i - \text{ промежуточный выход} $

# %% [markdown]
# $ \text{Пусть } \mathcal{W} \text{ множество всевозможных слов или словарь. Тогда под поисковым запросом будем подразумевать элемент множества } \mathcal{W}^* \text{. Если }  \mathcal{q} \text{ поисковый запрос, то есть } \mathcal{q} \in \mathcal{W}^* \text{ то его можно представить ввиде } \{\mathcal{w}_i\}_{i=1}^n \text{ где } \mathcal{w}_i \in \mathcal{W} \text{. В таком случае префиксом поискового запроса } \mathcal{q} \text{ длины } \mathcal{l} \text{ будем называть множество } \{\mathcal{w}_i\}_{i=1}^l \text{, а словом, следующим за префиксом длины } \mathcal{l} \text{ будем называть } \mathcal{w_{l+1}}.$
#
# $\text{Изачально представлен корпус поисковых запросов } \{\mathcal{q_i}\}_{i=1}^N \text{ На его основании строится пара } X = \{x_i\}_{i=1}^M \text{ и } y = \{y_i\}_{i=1}^M \text{, где } X  \text{ образуется из всевозможных префиксов исходного корпуса, а } y \text{ получается из слов, следующих за соотвествующим префиксом. } $
#
# $\text{Основной задачей данной работы является построение функции, оценивающей по префиксу следующее за ним слово, то есть некоторой функцию } \mathcal{f}: \mathcal{W}^* \rightarrow \mathcal{W} \text{. То есть решается задача классификации.}$
#
# $\text{Предположим, что } \mathcal{\hat{f}} \text{ оценка данной функции. Тогда в качестве основной метрики качества будем использовать } \frac{1}{M} \sum_{i=1}^M  \mathcal{I}[\mathcal{\hat{f}}(x_i) = y_i]$
#
# $\text{Так как в работе предполагается использовать нейронные сети, нужно также объявить функцию потерь. В данном случае это negative log likelyhood} $

# %% [markdown]
# здесь будет график с точками качества, то есть биграмма 14 процентов, LSTM - 15 процентов, часть речи 15,6 или attention 15,7 наконец итоговая 16,8

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
plt.figure(figsize=(12, 7))
sns.set_style("whitegrid")

plt.plot([1, 2], [14.025245, 15.07290906], color='grey')
plt.plot([2, 3], [15.07290906, 15.57782698], color='grey')
plt.plot([2, 3], [15.07290906, 15.67687577], color='grey')
plt.plot([3, 4], [15.57782698, 16.84089344], color='grey')
plt.plot([3, 4], [15.67687577, 16.84089344], color='grey')
plt.scatter([1, 2, 3, 3, 4], [14.025245, 15.07290906, 15.57782698, 15.67687577, 16.84089344], color='grey', s=70)

plt.xlim([1-0.7, 4+0.2])
plt.ylim([14-0.2, 17+0.2])
plt.show()
